# %%
import pandas as pd
import sys
sys.path.append("../")
import src.Resources as src

# %%
recomendation = pd.read_csv("../Data/recomendation.csv",index_col=0)

# %%
src.matrix(recomendation)

# %%
recomended_df = src.top("Terminator","Movie")

# %%
recomended_df
# Out:
#                                                    Image  \
# 10307  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 12113  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 13504  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 10476  https://m.media-amazon.com/images/M/MV5BNzhlYj...
# 11007  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 10822  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 11792  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 10370  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 10559  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 11409  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                            Title  Rating    Votes  \
# 10307              Terminator 2: El juicio final     8.6  1116320
# 12113                                    Nemesis     5.4     6317
# 13504                                   Returner     6.4    11414
# 10476                 Terminator: Destino oscuro     6.2   183054
# ...

# %%
recomended_book_df = recomended_df[recomended_df["Type"] == "Book"]
recomended_movie_df = recomended_df[recomended_df["Type"] == "Movie"]

# %%
recomended_book_df.head()
# Out:
#                   Title                                              Image  \
# 7573   Children of Ruin  https://images-na.ssl-images-amazon.com/images...
# 7630  The Ship Who Sang  https://images-na.ssl-images-amazon.com/images...
# 1246           Specials  https://images-na.ssl-images-amazon.com/images...
# 7555               2312  https://images-na.ssl-images-amazon.com/images...
# 7548           Babel-17  https://images-na.ssl-images-amazon.com/images...
#
#                Genre                                        Description  \
# 7573          Sci-Fi  The astonishing sequel to Children of Time, th...
# 7630  Fantasy|Sci-Fi  Helva had been born human, but only her brain ...
# 1246    Adult|Sci-Fi  "Special Circumstances": The words have sent c...
# 7555          Sci-Fi  The year is 2312. Scientific and technological...
# 7548          Sci-Fi  Babel-17 is all about the power of language. H...
#
#       Rating   Votes  Type                Title_id  similarity
# ...

# %%
recomended_movie_df.head()
# Out:
#                                Title  \
# 10307  Terminator 2: El juicio final
# 12113                        Nemesis
# 13504                       Returner
# 10476     Terminator: Destino oscuro
# 11007                       Número 9
#
#                                                    Image  \
# 10307  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 12113  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 13504  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 10476  https://m.media-amazon.com/images/M/MV5BNzhlYj...
# 11007  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                             Genre  \
# 10307               Action|Sci-Fi
# 12113      Action|Sci-Fi|Thriller
# 13504     Action|Adventure|Sci-Fi
# 10476     Action|Adventure|Sci-Fi
# 11007  Animation|Action|Adventure
#
#                                              Description  Rating    Votes  \
# 10307  A cyborg, identical to the one who failed to k...     8.6  1116320
# ...
