# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("../Data/Movies_clean.csv",index_col=0)

# %%
df.isnull().sum()
# Out:
# Movie_name             0
# Movie_img              0
# Movie_genre            0
# Movie_description      0
# Movie_rating           0
# Movie_votes            0
# Movie_directors        0
# Movie_stars          305
# dtype: int64

# %%
df = df.fillna("No stars")

# %%
df_filtered = df[df["Movie_votes"] > 1000]

# %%
df_filtered.isnull().sum()
# Out:
# Movie_name           0
# Movie_img            0
# Movie_genre          0
# Movie_description    0
# Movie_rating         0
# Movie_votes          0
# Movie_directors      0
# Movie_stars          0
# dtype: int64

# %%
df_numeric = df_filtered.select_dtypes(include=np.number)
df_numeric
# Out:
#         Movie_rating  Movie_votes
# 0                7.6        35423
# 1                8.3       106008
# 2                5.6        30998
# 3                7.7       349677
# 4                6.0       146485
# ...              ...          ...
# 130056           5.8         1668
# 130058           3.5         1829
# 130059           4.8         1248
# 130060           7.2         1270
# 130064           5.9         1619
#
# [53701 rows x 2 columns]

# %%
fig, ax = plt.subplots(2, 1, figsize=(20,15))

for i in range(len(df_numeric.columns)):
    sns.boxplot(x=df_numeric.columns[i], data=df_numeric, ax=ax[i])
plt.show()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 10))

lista_colores = ["blue", "green", "red", "cyan", "magenta", "orange","orange","blue","yellow","purple"]

axes = axes.flat

columnas_numeric = df_filtered.select_dtypes(include = np.number).columns

for i, colum in enumerate(columnas_numeric): 
    sns.histplot(
        data = df_filtered,
        x = colum,
        kde = True, 
        color = lista_colores[i], 
        line_kws = {"linewidth": 2}, 
        alpha = 0.2, 
        ax = axes[i])
    
    
    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")
    

fig.tight_layout();

# %%
df_categoric = df_filtered.select_dtypes(include=object)
df_categoric
# Out:
#                                       Movie_name  \
# 0       Dungeons & Dragons: Honor entre ladrones
# 1                                    John Wick 4
# 2                          Criminales a la vista
# 3                    Avatar: El sentido del agua
# 4                           Criminales en el mar
# ...                                          ...
# 130056                                 Peut-être
# 130058                           The Mad Monster
# 130059             The Strange World of Planet X
# 130060          Digimon Adventure tri. 2: Ketsui
# 130064                           Donovan's Brain
#
#                                                 Movie_img  \
# 0       https://m.media-amazon.com/images/M/MV5BZjAyMG...
# 1       https://m.media-amazon.com/images/M/MV5BMDExZG...
# 2       https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3       https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4       https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                   ...
# 130056  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 130058  https://m.media-amazon.com/images/M/MV5BZjFmZT...
# 130059  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 130060  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 130064  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                        Movie_genre  \
# 0          Action|Adventure|Comedy
# 1            Action|Crime|Thriller
# 2              Action|Comedy|Crime
# 3         Action|Adventure|Fantasy
# 4              Action|Comedy|Crime
# ...                            ...
# 130056         Comedy|Drama|Sci-Fi
# 130058        Drama|Horror|Romance
# 130059         Drama|Sci-Fi|Horror
# 130060  Animation|Action|Adventure
# 130064               Sci-Fi|Horror
#
#                                         Movie_description  \
# 0       A charming thief and a band of unlikely advent...
# 1       John Wick uncovers a path to defeating The Hig...
# 2       Full-time detectives Nick and Audrey are strug...
# 3       Jake Sully lives with his newfound family form...
# 4       A New York cop and his wife go on a European v...
# ...                                                   ...
# 130056  After having sex with his girlfriend Lucie in ...
# 130058  A mad scientist changes his simple-minded hand...
# 130059  A friendly visitor from outer space warns agai...
# 130060  The DigiDestined have a good time in a theme p...
# 130064  Three scientists unlawfully remove the still l...
#
#                            Movie_directors  \
# 0       JohnFrancisDaley|JonathanGoldstein
# 1                            ChadStahelski
# 2                           JeremyGarelick
# 3                             JamesCameron
# 4                            KyleNewacheck
# ...                                    ...
# 130056                      CédricKlapisch
# 130058                         SamNewfield
# 130059                         GilbertGunn
# 130060                     KeitarôMotonaga
# 130064                        FelixE.Feist
#
#                                               Movie_stars
# 0       ChrisPine|MichelleRodriguez|Regé-JeanPage|Just...
# 1       KeanuReeves|LaurenceFishburne|GeorgeGeorgiou|L...
# 2       AdamSandler|JenniferAniston|MarkStrong|Mélanie...
# 3       SamWorthington|ZoeSaldana|SigourneyWeaver|Step...
# 4       AdamSandler|JenniferAniston|LukeEvans|TerenceS...
# ...                                                   ...
# 130056  Jean-PaulBelmondo|RomainDuris|GéraldinePailhas...
# 130058     JohnnyDowns|GeorgeZucco|AnneNagel|GlennStrange
# 130059     ForrestTucker|GabyAndré|MartinBenson|AlecMango
# 130060  MihoArakawa|JohnEricBentley|JohnnyYongBosch|Ro...
# 130064         LewAyres|GeneEvans|NancyReagan|SteveBrodie
#
# [53701 rows x 6 columns]
