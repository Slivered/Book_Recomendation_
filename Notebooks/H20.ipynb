# %%
import pandas as pd
import sys
sys.path.append("../")
import src.Resources as src
import h2o
import gensim

# %%
h2o_df = pd.read_csv("../Data/recomendation.csv",index_col=0)
h2o_df
# Out:
#                                                    Image  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 24561  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24562  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24563  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24564  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24565  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                    Title  Rating    Votes  \
# 0                       Romeo and Juliet    7.48  2462752
# 1                                 Hamlet    8.04   888492
# 2                                Macbeth    7.80   836710
# ...

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 20.0.1+9-29, mixed mode, sharing)
#   Starting server from C:\Users\Sindri\anaconda3\envs\ironhack\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Sindri\AppData\Local\Temp\tmpqmtxa_wa
#   JVM stdout: C:\Users\Sindri\AppData\Local\Temp\tmpqmtxa_wa\h2o_Sindri_started_from_python.out
#   JVM stderr: C:\Users\Sindri\AppData\Local\Temp\tmpqmtxa_wa\h2o_Sindri_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Europe/Madrid
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.3
# H2O_cluster_version_age:    16 days
# ...

# %%
data = h2o.import_file("../Data/recomendation.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
model = gensim.models.Word2Vec(sentences=data, vector_size=100, window=5, min_count=1, workers=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Sindri\Documents\ironhack\Book_Recomendation_\Notebooks\H20.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sindri/Documents/ironhack/Book_Recomendation_/Notebooks/H20.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> model = gensim.models.Word2Vec(sentences=data, vector_size=100, window=5, min_count=1, workers=4)
#
# File c:\Users\Sindri\anaconda3\envs\ironhack\lib\site-packages\gensim\models\word2vec.py:429, in Word2Vec.__init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     427 if corpus_iterable is not None or corpus_file is not None:
# ...

# %%
articles = data["index"].unique().as_data_frame()["index"].tolist()
vectors = [model.wv[article] for article in articles]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sindri\anaconda3\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Sindri\anaconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Sindri\anaconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# ...
