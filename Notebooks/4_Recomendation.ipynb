# %%
import pandas as pd
import sys
sys.path.append("../")
import src.Resources as src

# %% [markdown]
# We load our DataFrame that's clean and ready to be used for the recomendation matrix.

# %%
recomendation = pd.read_csv("../Data/recomendation.csv",index_col=0)

# %%
recomendation.dropna(inplace=True)

# %%
recomendation
# Out:
#                                                    Image  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 24563  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24564  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24565  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24566  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24567  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                    Title  Rating    Votes  \
# 0                       Romeo and Juliet    7.48  2462752
# 1                                 Hamlet    8.04   888492
# 2                                Macbeth    7.80   836710
# 3                                Othello    7.78   368863
# 4              A Midsummer Night's Dream    7.90   513517
# ...                                  ...     ...      ...
# 24563  El gendarme y los extraterrestres    6.20     8890
# 24564                        The Capture    5.00     5442
# 24565                        Hunter Prey    5.80     6114
# 24566                          Infection    6.00     5614
# 24567                      Let's Be Evil    3.80     5539
#
#                           Genre  \
# 0                       Romance
# 1                         Drama
# 2                        Family
# 3                         Drama
# 4                       Fantasy
# ...                         ...
# 24563       Comedy|Crime|Sci-Fi
# 24564           Sci-Fi|Thriller
# 24565           Sci-Fi|Thriller
# 24566       Drama|Horror|Sci-Fi
# 24567  Horror|Reality-TV|Sci-Fi
#
#                                              Description   Type  \
# 0      In Romeo and Juliet, Shakespeare creates a vio...   Book
# 1      Among Shakespeare's plays, "Hamlet" is conside...   Book
# 2      One night on the heath, the brave and respecte...   Book
# 3      In Othello, Shakespeare creates a powerful dra...   Book
# 4      Shakespeare's intertwined love polygons begin ...   Book
# ...                                                  ...    ...
# 24563  In St. Tropez, French gendarme Cruchot and his...  Movie
# 24564  A group of scientists discover a soul guide an...  Movie
# 24565  A spaceship crashes on a desert planet with 3 ...  Movie
# 24566  INFECTION takes place in a dark, isolated hosp...  Movie
# 24567                     A vision of augmented reality.  Movie
#
#                                       Title_id
# 0                        Romeo and Juliet_Book
# 1                                  Hamlet_Book
# 2                                 Macbeth_Book
# 3                                 Othello_Book
# 4               A Midsummer Night's Dream_Book
# ...                                        ...
# 24563  El gendarme y los extraterrestres_Movie
# 24564                        The Capture_Movie
# 24565                        Hunter Prey_Movie
# 24566                          Infection_Movie
# 24567                      Let's Be Evil_Movie
#
# [24568 rows x 8 columns]

# %% [markdown]
# We execute the function that prepares the correlation matrix, this function saves two .pkl files that will be used later to do the recomendation, these two pkl ill leave them in a dropbox or drive in github so you can download them.
# Anyways you can execute the code and you will generate these two files but it can take a while and you need quite a lot of RAM memmory.

# %%
src.matrix(recomendation)
