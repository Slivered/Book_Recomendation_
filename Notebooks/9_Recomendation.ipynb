# %%
import pandas as pd
import sys
sys.path.append("../")
import src.Resources as src
# Out:
# [WDM] - Downloading: 100%|██████████| 6.80M/6.80M [00:00<00:00, 50.4MB/s]

# %%
recomendation = pd.read_csv("../Data/recomendation.csv",index_col=0)

# %%
src.matrix(recomendation)

# %%
recomended_df = src.top("Toy Story")

# %%
recomended_book_df = recomended_df[recomended_df["Type"] == "Book"]
recomended_movie_df = recomended_df[recomended_df["Type"] == "Movie"]

# %%
recomended_book_df.head()
# Out:
#                        Title  \
# 2856  極主夫道 1 [Gokushufudō 1]
# 3201  極主夫道 3 [Gokushufudō 3]
# 3314            SPY×FAMILY 9
# 1678            Spy×Family 5
# 8466  ワンパンマン 7 [Wanpanman 7]
#
#                                                   Image             Genre  \
# 2856  https://images-na.ssl-images-amazon.com/images...  Animation|Comedy
# 3201  https://images-na.ssl-images-amazon.com/images...  Animation|Comedy
# 3314  https://images-na.ssl-images-amazon.com/images...  Animation|Comedy
# 1678  https://images-na.ssl-images-amazon.com/images...  Animation|Comedy
# 8466  https://images-na.ssl-images-amazon.com/images...  Animation|Comedy
#
#                                             Description  Rating  Votes  Type  \
# 2856  元・最凶ヤクザが選んだのは、主夫としての道だった――。! 話題の新鋭作家がおくる、アットホー...    8.64  20401  Book
# 3201  コミックス累計70万部突破&2018年度マンガ賞、続々受賞! ! 伝説のヤクザが専業主夫に転...    8.74   5502  Book
# 3314  ヨルvs暗殺者集団の戦いは終局へ…!!　その一方で、豪華客船には爆弾が仕掛けられていた――！...    9.04   6315  Book
# 1678  予知犬のボンドが家族に加わり、オペレーション〈梟（ストリクス）〉もフォージャー家もようやく軌...    8.94  18949  Book
# 8466  宇宙人による地球侵略に、S級ヒーロー達は反撃の糸口をつかみ攻勢に立つ。一方、敵母船内でボロス...    9.04   5558  Book
#
#                          Title_id  similarity
# 2856  極主夫道 1 [Gokushufudō 1]_Book   -0.279263
# 3201  極主夫道 3 [Gokushufudō 3]_Book   -0.279263
# 3314            SPY×FAMILY 9_Book   -0.279263
# 1678            Spy×Family 5_Book   -0.279263
# 8466  ワンパンマン 7 [Wanpanman 7]_Book   -0.279263

# %%
recomended_movie_df.head()
# Out:
#                                             Title  \
# 13869                                 Toy Story 4
# 14759                Justin y la espada del valor
# 13868                    Gru: Mi villano favorito
# 14481  La vuelta al mundo de Alvin y las ardillas
# 13891                 La fiesta de las salchichas
#
#                                                    Image  \
# 13869  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14759  https://m.media-amazon.com/images/M/MV5BNTE3YW...
# 13868  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14481  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 13891  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                             Genre  \
# 13869  Animation|Adventure|Comedy
# 14759  Animation|Adventure|Comedy
# 13868  Animation|Adventure|Comedy
# 14481  Animation|Adventure|Comedy
# 13891  Animation|Adventure|Comedy
#
#                                              Description  Rating   Votes  \
# 13869  When a new toy called "Forky" joins Woody and ...     7.7  259285
# 14759  A young boy grows up as he embarks on a quest ...     6.0    6256
# 13868  When a criminal mastermind uses a trio of orph...     7.6  557583
# 14481  The Chipmunks compete with the Chipettes in a ...     7.2    5675
# 13891  A sausage strives to discover the truth about ...     6.1  199750
#
#         Type                                          Title_id  similarity
# 13869  Movie                                 Toy Story 4_Movie   -0.351230
# 14759  Movie                Justin y la espada del valor_Movie   -0.285984
# 13868  Movie                    Gru: Mi villano favorito_Movie   -0.269454
# 14481  Movie  La vuelta al mundo de Alvin y las ardillas_Movie   -0.264260
# 13891  Movie                 La fiesta de las salchichas_Movie   -0.255495
