# %%
import sys
sys.path.append("../")
import src.Resources as src

# %%
recomendation = pd.read_csv("../Data/recomendation.csv",index_col=0)

# %%
src.matrix(recomendation)

# %%
recomended_df = src.top("Toy Story 4")

# %%
recomended_book_df = recomended_df[recomended_df["Type"] == "Book"]
recomended_movie_df = recomended_df[recomended_df["Type"] == "Movie"]

# %%
recomended_book_df.head()
# Out:
#                                                Title  \
# 2989  The Hollow Chocolate Bunnies of the Apocalypse
# 3314                                    SPY×FAMILY 9
# 8466                          ワンパンマン 7 [Wanpanman 7]
# 3020                          極主夫道 2 [Gokushufudō 2]
# 1678                                    Spy×Family 5
#
#                                                   Image  \
# 2989  https://images-na.ssl-images-amazon.com/images...
# 3314  https://images-na.ssl-images-amazon.com/images...
# 8466  https://images-na.ssl-images-amazon.com/images...
# 3020  https://images-na.ssl-images-amazon.com/images...
# 1678  https://images-na.ssl-images-amazon.com/images...
#
#                        Genre  \
# 2989  Mystery|Fantasy|Comedy
# 3314        Animation|Comedy
# 8466        Animation|Comedy
# 3020        Animation|Comedy
# 1678        Animation|Comedy
#
#                                             Description  Rating  Votes  Type  \
# 2989  Toy Town—older, bigger, and certainly not wise...    7.50   8061  Book
# 3314  ヨルvs暗殺者集団の戦いは終局へ…!!　その一方で、豪華客船には爆弾が仕掛けられていた――！...    9.04   6315  Book
# 8466  宇宙人による地球侵略に、S級ヒーロー達は反撃の糸口をつかみ攻勢に立つ。一方、敵母船内でボロス...    9.04   5558  Book
# 3020  最強主夫は、元極道! ? 伝説のヤクザ、不死身の龍。そんな彼が足を洗い選んだ道は、専業主夫だ...    8.76   7787  Book
# 1678  予知犬のボンドが家族に加わり、オペレーション〈梟（ストリクス）〉もフォージャー家もようやく軌...    8.94  18949  Book
#
#                                                Title_id  similarity
# 2989  The Hollow Chocolate Bunnies of the Apocalypse...   -0.251405
# 3314                                  SPY×FAMILY 9_Book   -0.247808
# 8466                        ワンパンマン 7 [Wanpanman 7]_Book   -0.247808
# 3020                        極主夫道 2 [Gokushufudō 2]_Book   -0.247808
# 1678                                  Spy×Family 5_Book   -0.247808

# %%
recomended_movie_df.head()
# Out:
#                       Title  \
# 13924           Toy Story 2
# 13795             Toy Story
# 14102  Oliver y su pandilla
# 14503    La banda del patio
# 14774               Karwaan
#
#                                                    Image  \
# 13924  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 13795  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14102  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14503  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14774  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                             Genre  \
# 13924  Animation|Adventure|Comedy
# 13795  Animation|Adventure|Comedy
# 14102  Animation|Adventure|Comedy
# 14503  Animation|Adventure|Comedy
# 14774      Adventure|Comedy|Drama
#
#                                              Description  Rating    Votes  \
# 13924  When Woody is stolen by a toy collector, Buzz ...     7.9   592010
# 13795  A cowboy doll is profoundly threatened and jea...     8.3  1011075
# 14102  A lost and alone kitten joins a gang of dogs e...     6.6    50273
# 14503  T.J. and the gang must save summer vacation fr...     6.5    11087
# 14774  Two friends and a chirpy teenager take a road ...     7.6    16480
#
#         Type                    Title_id  similarity
# 13924  Movie           Toy Story 2_Movie   -0.525185
# 13795  Movie             Toy Story_Movie   -0.351230
# 14102  Movie  Oliver y su pandilla_Movie   -0.302476
# 14503  Movie    La banda del patio_Movie   -0.281008
# 14774  Movie               Karwaan_Movie   -0.277094
